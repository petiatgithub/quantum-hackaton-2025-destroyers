# %%
import numpy as np



starting_positions =[(4,0),(6,0),(5,1),(5,3),(3,3),(1,3),(1,1),(3,1)]
circle_positions =[(4,3),(3,3),(2,3),(1,3),(1,2),(1,1),(2,1), (3,1), (4,1), (5,1), (5,2), (5,3)]
circle_start = [(4,0), (5,0), (6,0),(6,1), (6,2), (6,3), (5,3)]

position_list  = circle_start + circle_positions +circle_positions +circle_positions +circle_positions
current_position = starting_positions
active_ions = [1]*8
time = 0

def check_for_special_position(current_state):
    if current_state[7] == (3,1):
        active_ions[7]=0
    if current_state[6] == (5, 1):
        active_ions[6] = 0
    if current_state[5] == (5,3):
        active_ions[5] = 0
    if current_state[4] == (3, 3) and not time== 0:
        active_ions[4] = 0
    if current_state[3] == (1, 3):
        active_ions[3] = 0
    if current_state[2] == (1, 1):
        active_ions[2] = 0

def shift_positions(active_ion, current_state):
    new_state = current_state.copy()
    active_ions = check_for_special_position(current_state)
    for i in range(8):
        if active_ion[i] == 1:
            pos = position_list.index(current_state[i])
            new_state[i] = position_list[pos+1]
    return new_state

def walk_out(current_state):
    new_state = []
    for state in current_state:
        if state[1] == 0:
            new_state.append(state)
        if state[1] ==1:
            new_state.append((state[0],0))
        if state[1] == 2:
            new_state.append(state)
        if state[1] == 3:
            new_state.append((state[0],4))
    return new_state


def cycle(current_state):
    next_moves =[]
    inner_position = shift_positions(active_ions, current_state)
    inner_position_react = shift_positions(active_ions, inner_position)
    outer_position = walk_out(inner_position)
    next_moves.append(inner_position)
    next_moves.append(outer_position)
    next_moves.append(inner_position)
    next_moves.append(inner_position_react)
    next_moves.append(inner_position_react)
    next_moves.append(inner_position_react)
    
    return next_moves

    

    

moves =[]
moves.append(current_position)
moves.append(current_position)
moves.append(shift_positions(active_ions, current_position))

# %%
def walk_out(current_state):
    new_state = []
    for state in current_state:
        if state[1] == 0:
            new_state.append(state)
        if state[1] ==1:
            new_state.append((state[0],0))
        if state[1] == 2:
            new_state.append(state)
        if state[1] == 3:
            new_state.append((state[0],4))
    return new_state

# %%
cycle([(4,0),(6,0),(5,1),(5,3),(3,3),(1,3),(1,1),(3,1)])
# Out:
# [[(5, 0), (6, 1), (5, 2), (3, 1), (3, 3), (1, 2), (2, 1), (3, 1)],
#  [(5, 0), (6, 0), (5, 2), (3, 0), (3, 4), (1, 2), (2, 0), (3, 0)],
#  [(5, 0), (6, 0), (5, 2), (3, 0), (3, 4), (1, 2), (2, 0), (3, 0)],
#  [(5, 0), (6, 0), (5, 2), (3, 0), (3, 4), (1, 2), (2, 0), (3, 0)],
#  [(5, 0), (6, 1), (5, 2), (3, 1), (3, 3), (1, 2), (2, 1), (3, 1)],
#  [(6, 0), (6, 2), (5, 3), (4, 1), (3, 3), (1, 1), (3, 1), (3, 1)],
#  [(6, 0), (6, 2), (5, 3), (4, 1), (3, 3), (1, 1), (3, 1), (3, 1)],
#  [(6, 0), (6, 2), (5, 3), (4, 1), (3, 3), (1, 1), (3, 1), (3, 1)]]

# %%
active_ions = [1, 1, 1, 1, 1, 1, 1, 0]
cycle([(6, 2), (5, 3), (3, 3), (1, 3), (1, 1), (3, 1), (5, 1), (3, 1)])
# Out:
# [[(6, 3), (4, 3), (2, 3), (1, 3), (2, 1), (4, 1), (5, 1), (3, 1)],
#  [(6, 4), (4, 4), (2, 4), (1, 4), (2, 0), (4, 0), (5, 0), (3, 0)],
#  [(6, 3), (4, 3), (2, 3), (1, 3), (2, 1), (4, 1), (5, 1), (3, 1)],
#  [(5, 3), (3, 3), (1, 3), (1, 3), (3, 1), (5, 1), (5, 1), (3, 1)],
#  [(5, 3), (3, 3), (1, 3), (1, 3), (3, 1), (5, 1), (5, 1), (3, 1)],
#  [(5, 3), (3, 3), (1, 3), (1, 3), (3, 1), (5, 1), (5, 1), (3, 1)]]

# %%
shift_positions([1]*8, [(5, 0), (6, 1), (5, 2), (4, 3), (3, 3), (1, 2), (2, 1), (3, 1)])
# Out:
# [(6, 0), (6, 2), (5, 3), (3, 3), (2, 3), (1, 1), (3, 1), (4, 1)]

# %%
walk_out([(1,1), (3,1), (2,2), (4,3)])
# Out:
# [(1, 0), (3, 0), (2, 2), (4, 4)]

# %%
gate_schedule = [[('RX', 0.7853981633974492, 0), ('RY', 1.5707963267948966, 1), ('RY', 1.5707963267948966, 2), ('RY', 1.5707963267948966, 3), ('RY', 1.5707963267948966, 4), ('RY', 1.5707963267948966, 5), ('RY', 1.5707963267948966, 6), ('RY', 1.5707963267948966, 7)], 
                 [('RX', 3.141592653589793, 1), ('RX', 3.141592653589793, 2), ('RX', 3.141592653589793, 3), ('RX', 3.141592653589793, 4), ('RX', 3.141592653589793, 5), ('RX', 3.141592653589793, 6), ('RX', 3.141592653589793, 7)], 
                 [('MS', -0.7853981633974483, (1, 0))], 
                 [('RX', 0.3926990816987228, 0), ('RY', 1.5707963267948963, 1)], [('RX', -2.356194490192345, 1), ('MS', -0.39269908169872414, (2, 0))], [('RX', 0.1963495408493614, 0), ('MS', -0.7853981633974483, (2, 1))], [('RX', 0.3926990816987228, 1), ('RY', 1.5707963267948963, 2), ('MS', -0.19634954084936207, (3, 0))], [('RX', -2.356194490192345, 2), ('RX', 0.0981747704246807, 0), ('MS', -0.39269908169872414, (3, 1))], [('RX', 0.1963495408493614, 1), ('MS', -0.7853981633974483, (3, 2)), ('MS', -0.09817477042468103, (4, 0))], [('RX', 0.3926990816987228, 2), ('RY', 1.5707963267948963, 3), ('RX', 0.04908738521234035, 0), ('MS', -0.19634954084936207, (4, 1))], [('RX', -2.356194490192345, 3), ('RX', 0.0981747704246807, 1), ('MS', -0.39269908169872414, (4, 2)), ('MS', -0.04908738521234052, (5, 0))], [('RX', 0.1963495408493614, 2), ('MS', -0.7853981633974483, (4, 3)), ('RX', 0.024543692606169287, 0), ('MS', -0.09817477042468103, (5, 1))], [('RX', 0.3926990816987228, 3), ('RY', 1.5707963267948963, 4), ('RX', 0.04908738521234035, 1), ('MS', -0.19634954084936207, (5, 2)), ('MS', -0.02454369260617026, (6, 0))], [('RX', -2.356194490192345, 4), ('RX', 0.0981747704246807, 2), ('MS', -0.39269908169872414, (5, 3)), ('RX', 0.012271846303084644, 0), ('MS', -0.04908738521234052, (6, 1))], [('RX', 0.1963495408493614, 3), ('MS', -0.7853981633974483, (5, 4)), ('RX', 0.024543692606169287, 1), ('MS', -0.09817477042468103, (6, 2)), ('MS', -0.01227184630308513, (7, 0))], [('RX', 0.3926990816987228, 4), ('RY', 1.5707963267948963, 5), ('RX', 0.04908738521234035, 2), ('MS', -0.19634954084936207, (6, 3)), ('RX', -3.141592653589793, 0), ('MS', -0.02454369260617026, (7, 1))], [('RX', -2.356194490192345, 5), ('RX', 0.0981747704246807, 3), ('MS', -0.39269908169872414, (6, 4)), ('RX', -3.141592653589793, 1), ('MS', -0.04908738521234052, (7, 2))], [('RX', 0.1963495408493614, 4), ('MS', -0.7853981633974483, (6, 5)), ('RX', -3.141592653589793, 2), ('MS', -0.09817477042468103, (7, 3))], [('RX', 0.3926990816987228, 5), ('RY', 1.5707963267948963, 6), ('RY', 1.5707963267948966, 3), ('MS', -0.19634954084936207, (7, 4))], [('RX', -2.356194490192345, 6), ('RX', 3.141592653589793, 3), ('RY', 1.5707963267948966, 4), ('MS', -0.39269908169872414, (7, 5))], [('RX', 3.141592653589793, 4), ('RY', 1.5707963267948966, 5), ('MS', -0.7853981633974483, (7, 6))], [('RX', 3.141592653589793, 5), ('MS', 1.5707963267948966, (0, 7)), ('RY', 1.5707963267948966, 6)], [('MS', 1.5707963267948966, (2, 5)), ('RX', -1.5707963267948966, 0), ('RX', 3.141592653589793, 6), ('RX', -1.5707963267948966, 7)], [('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RY', -1.5707963267948966, 0), ('MS', 1.5707963267948966, (1, 6)), ('RY', 1.5707963267948966, 7)], [('RY', -1.5707963267948966, 2), ('RY', 1.5707963267948966, 5), ('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6), ('MS', 1.5707963267948966, (7, 0))], [('MS', 1.5707963267948966, (5, 2)), ('RY', -1.5707963267948966, 1), ('RY', 1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RX', -1.5707963267948966, 7)], [('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('MS', 1.5707963267948966, (6, 1)), ('RY', 1.5707963267948966, 0), ('RY', -1.5707963267948966, 7)], [('RY', 1.5707963267948966, 2), ('RY', -1.5707963267948966, 5), ('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6), ('MS', 1.5707963267948966, (0, 7))], [('MS', 1.5707963267948966, (2, 5)), ('RY', 1.5707963267948966, 1), ('RY', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RX', -1.5707963267948966, 7)], [('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('MS', 1.5707963267948966, (1, 6)), ('RY', -1.5707963267948966, 0)], [('RY', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6)], [('RY', -1.5707963267948966, 1)]]

# %%
def split_tasks(schedule):
    new_schedule =[]
    
    for task in schedule:
        single =[]
        double = []
        for gate in task:
            if gate[0] == "MS":
                double.append(gate)
            else:
                single.append(gate)
        print(single, "\n")
        #print([], "\n")
        print(double, "\n")

handmade_schedule=[[('RX', 0.7853981633974492, 0), ('RY', 1.5707963267948966, 1), ('RY', 1.5707963267948966, 2), ('RY', 1.5707963267948966, 3), ('RY', 1.5707963267948966, 4), ('RY', 1.5707963267948966, 5), ('RY', 1.5707963267948966, 6), ('RY', 1.5707963267948966, 7)],
                  [('RX', 3.141592653589793, 1), ('RX', 3.141592653589793, 2), ('RX', 3.141592653589793, 3), ('RX', 3.141592653589793, 4), ('RX', 3.141592653589793, 5), ('RX', 3.141592653589793, 6), ('RX', 3.141592653589793, 7)],
                  [('MS', -0.7853981633974483, (1, 0))],
                  [('RX', 0.3926990816987228, 0), ('RY', 1.5707963267948963, 1)],
                  [('MS', -0.39269908169872414, (2, 0))],
                  [('RX', -2.356194490192345, 1),('RX', 0.1963495408493614, 0)],
                  [('MS', -0.7853981633974483, (2, 1)), ('MS', -0.19634954084936207, (3, 0))],
                  [('RX', 0.3926990816987228, 1), ('RY', 1.5707963267948963, 2)],
                  [('RX', -2.356194490192345, 2), ('RX', 0.0981747704246807, 0)],
                  [('MS', -0.39269908169872414, (3, 1)), ('MS', -0.09817477042468103, (4, 0))],
                  [('RX', 0.1963495408493614, 1),('RX', 0.04908738521234035, 0)],
                  [('MS', -0.7853981633974483, (3, 2)), ('MS', -0.19634954084936207, (4, 1)),('MS', -0.04908738521234052, (5, 0))],
                  [('RX', 0.024543692606169287, 0), ('RX', 0.0981747704246807, 1),('RX', 0.3926990816987228, 2), ('RY', 1.5707963267948963, 3) ],
                  [('RX', -2.356194490192345, 3)],
                  [('MS', -0.39269908169872414, (4, 2)),('MS', -0.09817477042468103, (5, 1)), ('MS', -0.02454369260617026, (6, 0))],
                  [('RX', 0.012271846303084644, 0), ('RX', 0.04908738521234035, 1), ('RX', 0.1963495408493614, 2), ('RX', 0.3926990816987228, 3), ('RY', 1.5707963267948963, 4)],
                  [[('RX', -2.356194490192345, 4),  ('RX', 0.1963495408493614, 3)]],
                  [('MS', -0.01227184630308513, (7, 0)), ('MS', -0.04908738521234052, (6, 1)), ('MS', -0.19634954084936207, (5, 2))('MS', -0.7853981633974483, (4, 3))],
                  [('RX', -3.141592653589793, 0), ('RX', 0.0981747704246807, 2), ('RX', 0.024543692606169287, 1)],
                  [('MS', -0.39269908169872414, (5, 3)), ('MS', -0.02454369260617026, (7, 1)) ('MS', -0.09817477042468103, (6, 2))],
                  [('RX', -2.356194490192345, 5), ('RX', -3.141592653589793, 1), ('RX', 0.04908738521234035, 2),('RX', 0.1963495408493614, 3)],
                  [('MS', -0.7853981633974483, (5, 4)),('MS', -0.19634954084936207, (6, 3)),('MS', -0.04908738521234052, (7, 2))],
                  [ ('RX', -3.141592653589793, 2), ('RX', 0.0981747704246807, 3), ('RX', 0.3926990816987228, 4), ('RY', 1.5707963267948963, 5)],
                  [ ('MS', -0.09817477042468103, (7, 3)), ('MS', -0.39269908169872414, (6, 4))],
                  [('RY', 1.5707963267948966, 3),('RX', 0.1963495408493614, 4)],
                  [('MS', -0.7853981633974483, (6, 5)), ('MS', -0.19634954084936207, (7, 4))],
                  [('RX', 0.3926990816987228, 5), ('RY', 1.5707963267948963, 6)],
                  [('RX', -2.356194490192345, 6), ('RX', 3.141592653589793, 3), ('RY', 1.5707963267948966, 4)],
                  [('MS', -0.39269908169872414, (7, 5))],
                  [('RX', 3.141592653589793, 4), ('RY', 1.5707963267948966, 5)] ,
                  [('MS', -0.7853981633974483, (7, 6))],
                  [('RX', 3.141592653589793, 5), ('RY', 1.5707963267948966, 6)] ,
                  [('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))], 
                  [('RX', 3.141592653589793, 6),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RY', -1.5707963267948966, 0), ('RY', 1.5707963267948966, 7)], 
                  [('RY', -1.5707963267948966, 2), ('RY', 1.5707963267948966, 5), ('RX', -1.5707963267948966, 0),('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 7)], 
                  [('MS', 1.5707963267948966, (7, 0)), ('MS', 1.5707963267948966, (5, 2)), ('MS', 1.5707963267948966, (6, 1))], 
                  [('RY', -1.5707963267948966, 1), ('RY', 1.5707963267948966, 2)('RY', 1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RY', -1.5707963267948966, 5),('RX', -1.5707963267948966, 7)], 
                  [('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 6),('RX', -1.5707963267948966, 5), ('RY', 1.5707963267948966, 0), ('RY', -1.5707963267948966, 7)], 
                  [('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))], 
                  [('RY', 1.5707963267948966, 1), ('RY', -1.5707963267948966, 2), ('RY', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RX', -1.5707963267948966, 7)], 
                  [('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RX', -1.5707963267948966, 6),('RY', -1.5707963267948966, 0)], 
                  [],
                  [('RY', -1.5707963267948966, 1)] ]

# %%
handmade_schedule=[[('RX', 0.7853981633974492, 0), ('RY', 1.5707963267948966, 1), ('RY', 1.5707963267948966, 2), ('RY', 1.5707963267948966, 3), ('RY', 1.5707963267948966, 4), ('RY', 1.5707963267948966, 5), ('RY', 1.5707963267948966, 6), ('RY', 1.5707963267948966, 7)],
                  [('RX', 3.141592653589793, 1), ('RX', 3.141592653589793, 2), ('RX', 3.141592653589793, 3), ('RX', 3.141592653589793, 4), ('RX', 3.141592653589793, 5), ('RX', 3.141592653589793, 6), ('RX', 3.141592653589793, 7)],
                  [('MS', -0.7853981633974483, (1, 0))],
                  [('RX', 0.3926990816987228, 0), ('RY', 1.5707963267948963, 1)],
                  [('MS', -0.39269908169872414, (2, 0))],
                  [('RX', -2.356194490192345, 1),('RX', 0.1963495408493614, 0)],
                  [('MS', -0.7853981633974483, (2, 1)), ('MS', -0.19634954084936207, (3, 0))],
                  [('RX', 0.3926990816987228, 1), ('RY', 1.5707963267948963, 2)],
                  [('RX', -2.356194490192345, 2), ('RX', 0.0981747704246807, 0)],
                  [('MS', -0.39269908169872414, (3, 1)), ('MS', -0.09817477042468103, (4, 0))],
                  [('RX', 0.1963495408493614, 1),('RX', 0.04908738521234035, 0)],
                  [('MS', -0.7853981633974483, (3, 2)), ('MS', -0.19634954084936207, (4, 1)),('MS', -0.04908738521234052, (5, 0))],
                  [('RX', 0.024543692606169287, 0), ('RX', 0.0981747704246807, 1),('RX', 0.3926990816987228, 2), ('RY', 1.5707963267948963, 3) ],
                  [('RX', -2.356194490192345, 3)],
                  [('MS', -0.39269908169872414, (4, 2)),('MS', -0.09817477042468103, (5, 1)), ('MS', -0.02454369260617026, (6, 0))],
                  [('RX', 0.012271846303084644, 0), ('RX', 0.04908738521234035, 1), ('RX', 0.1963495408493614, 2), ('RX', 0.3926990816987228, 3), ('RY', 1.5707963267948963, 4)],
                  [('RX', -2.356194490192345, 4),  ('RX', 0.1963495408493614, 3)],
                  [('MS', -0.01227184630308513, (7, 0)), ('MS', -0.04908738521234052, (6, 1)), ('MS', -0.19634954084936207, (5, 2)),('MS', -0.7853981633974483, (4, 3))],
                  [('RX', -3.141592653589793, 0), ('RX', 0.0981747704246807, 2), ('RX', 0.024543692606169287, 1)],
                  [('MS', -0.39269908169872414, (5, 3)), ('MS', -0.02454369260617026, (7, 1)), ('MS', -0.09817477042468103, (6, 2))],
                  [('RX', -2.356194490192345, 5), ('RX', -3.141592653589793, 1), ('RX', 0.04908738521234035, 2),('RX', 0.1963495408493614, 3)],
                  [('MS', -0.7853981633974483, (5, 4)),('MS', -0.19634954084936207, (6, 3)),('MS', -0.04908738521234052, (7, 2))],
                  [ ('RX', -3.141592653589793, 2), ('RX', 0.0981747704246807, 3), ('RX', 0.3926990816987228, 4), ('RY', 1.5707963267948963, 5)],
                  [ ('MS', -0.09817477042468103, (7, 3)), ('MS', -0.39269908169872414, (6, 4))],
                  [('RY', 1.5707963267948966, 3),('RX', 0.1963495408493614, 4)],
                  [('MS', -0.7853981633974483, (6, 5)), ('MS', -0.19634954084936207, (7, 4))],
                  [('RX', 0.3926990816987228, 5), ('RY', 1.5707963267948963, 6)],
                  [('RX', -2.356194490192345, 6), ('RX', 3.141592653589793, 3), ('RY', 1.5707963267948966, 4)],
                  [('MS', -0.39269908169872414, (7, 5))],
                  [('RX', 3.141592653589793, 4), ('RY', 1.5707963267948966, 5)] ,
                  [('MS', -0.7853981633974483, (7, 6))],
                  [('RX', 3.141592653589793, 5), ('RY', 1.5707963267948966, 6)] ,
                  [('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))], 
                  [('RX', 3.141592653589793, 6),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RY', -1.5707963267948966, 0), ('RY', 1.5707963267948966, 7)], 
                  [('RY', -1.5707963267948966, 2), ('RY', 1.5707963267948966, 5), ('RX', -1.5707963267948966, 0),('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 7)], 
                  [('MS', 1.5707963267948966, (7, 0)), ('MS', 1.5707963267948966, (5, 2)), ('MS', 1.5707963267948966, (6, 1))], 
                  [('RY', -1.5707963267948966, 1), ('RY', 1.5707963267948966, 2),('RY', 1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RY', -1.5707963267948966, 5),('RX', -1.5707963267948966, 7)], 
                  [('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 6),('RX', -1.5707963267948966, 5), ('RY', 1.5707963267948966, 0), ('RY', -1.5707963267948966, 7)], 
                  [('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))], 
                  [('RY', 1.5707963267948966, 1), ('RY', -1.5707963267948966, 2), ('RY', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RX', -1.5707963267948966, 7)], 
                  [('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RX', -1.5707963267948966, 6),('RY', -1.5707963267948966, 0)], 
                  [],
                  [('RY', -1.5707963267948966, 1)] ]

# %%
 




[, ] 



 






 ####ACHTUNG

 



 

  






 



 












[('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))] 

[('RX', 3.141592653589793, 6),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RY', -1.5707963267948966, 0), ('RY', 1.5707963267948966, 7)] 

[('RY', -1.5707963267948966, 2), ('RY', 1.5707963267948966, 5), ('RX', -1.5707963267948966, 0),('RX', -1.5707963267948966, 1), ('RX', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 7)] 

[('MS', 1.5707963267948966, (7, 0)), ('MS', 1.5707963267948966, (5, 2)), ('MS', 1.5707963267948966, (6, 1))] 

[('RY', -1.5707963267948966, 1), ('RY', 1.5707963267948966, 2)('RY', 1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RY', -1.5707963267948966, 5),('RX', -1.5707963267948966, 7)] 

[('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 6),('RX', -1.5707963267948966, 5), ('RY', 1.5707963267948966, 0), ('RY', -1.5707963267948966, 7)] 

[('MS', 1.5707963267948966, (0, 7)), ('MS', 1.5707963267948966, (2, 5)), ('MS', 1.5707963267948966, (1, 6))] 

[('RY', 1.5707963267948966, 1), ('RY', -1.5707963267948966, 2), ('RY', -1.5707963267948966, 6), ('RX', -1.5707963267948966, 0), ('RX', -1.5707963267948966, 7)] 

[('RX', -1.5707963267948966, 1),('RX', -1.5707963267948966, 2), ('RX', -1.5707963267948966, 5), ('RX', -1.5707963267948966, 6),('RY', -1.5707963267948966, 0)] 

[] 

[('RY', -1.5707963267948966, 1)]

# %%
def what_comes_next(current_state, next_tasks):
    if test_bound_state_reacts(current_state, next_tasks) not == [False]*8:
        bound_state_move(current_state, next_tasks)
        ions_should_react_now(current_state, next_tasks)
